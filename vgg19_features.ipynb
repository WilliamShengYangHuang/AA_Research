# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamShengYangHuang/AA_Research/blob/main/vgg19_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip show keras
# !pip show tensorflow
# Out:
# Name: keras
# Version: 2.9.0
# Summary: Deep learning for humans.
# Home-page: https://keras.io/
# Author: Keras team
# Author-email: keras-users@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires:
# Required-by: tensorflow, keras-vis
# Name: tensorflow
# Version: 2.9.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: packaging, tensorflow-io-gcs-filesystem, setuptools, wrapt, absl-py, typing-extensions, astunparse, termcolor, flatbuffers, google-pasta, libclang, tensorboard, numpy, h5py, keras, keras-preprocessing, gast, grpcio, six, protobuf, opt-einsum, tensorflow-estimator
# Required-by: kapre

# %%
# !pip uninstall keras
# !pip uninstall tensorflow
# Out:
# Found existing installation: keras 2.9.0
# Uninstalling keras-2.9.0:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/keras-2.9.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/keras/*
# Proceed (y/n)? y
#   Successfully uninstalled keras-2.9.0
# Found existing installation: tensorflow 2.9.1
# Uninstalling tensorflow-2.9.1:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.9.1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.9.1

# %%
# !pip install keras==2.9.0
# !pip install tensorflow==2.9.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras==2.9.0
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Installing collected packages: keras
# Successfully installed keras-2.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.9.1
#   Using cached tensorflow-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (0.26.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.1.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (57.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.46.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.14.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (2.9.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (14.0.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (3.17.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.15.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (4.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (3.3.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (1.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.9.1) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow==2.9.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow==2.9.1) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow==2.9.1) (3.0.9)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.9.1

# %%
# !pip install keras_applications
# !pip install keras.engine.topology
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_applications in /usr/local/lib/python3.7/dist-packages (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras_applications) (1.21.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras_applications) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras_applications) (1.5.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement keras.engine.topology (from versions: none)
# ERROR: No matching distribution found for keras.engine.topology

# %%
from __future__ import print_function

import numpy as np
import warnings

from keras.models import Model
from keras.layers import Flatten, Dense, Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import GlobalAveragePooling2D
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras import backend as K
from keras.applications.imagenet_utils import decode_predictions
from keras.applications.imagenet_utils import preprocess_input
#from keras.applications.imagenet_utils import _obtain_input_shape
from keras_applications.imagenet_utils import _obtain_input_shape
#from keras.engine.topology import get_source_inputs
from keras.utils.layer_utils import get_source_inputs

# %%
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH_NO_TOP = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %%
def VGG19(include_top=True, weights='imagenet',
          input_tensor=None, input_shape=None,
          pooling=None,
          classes=1000):
   
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and include_top and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')
    # Determine proper input shape
    input_shape = _obtain_input_shape(input_shape,
                                      default_size=224,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                      require_flatten=include_top)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv4')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv4')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv4')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    if include_top:
        # Classification block
        x = Flatten(name='flatten')(x)
        x = Dense(4096, activation='relu', name='fc1')(x)
        x = Dense(4096, activation='relu', name='fc2')(x)
        x = Dense(classes, activation='softmax', name='predictions')(x)
    else:
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x)
        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input
    # Create model.
    model = Model(inputs, x, name='vgg19')

    # load weights
    if weights == 'imagenet':
        if include_top:
            weights_path = get_file('vgg19_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        else:
            weights_path = get_file('vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5',
                                    WEIGHTS_PATH_NO_TOP,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':
            if include_top:
                maxpool = model.get_layer(name='block5_pool')
                shape = maxpool.output_shape[1:]
                dense = model.get_layer(name='fc1')
                layer_utils.convert_dense_weights_data_format(dense, shape, 'channels_first')

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
if __name__ == '__main__':
    model = VGG19(include_top=True, weights='imagenet')
     
    img_path = '0-0.jpg'
    img = image.load_img(img_path, target_size=(224, 224))
   
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    print('Input image shape:', x.shape)

    preds = model.predict(x)
    print('Predicted:', decode_predictions(preds))
# Out:
# Input image shape: (1, 224, 224, 3)
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f1388ba27a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f1388ba27a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Predicted: [[('n04523525', 'vault', 0.105756335), ('n03160309', 'dam', 0.09146436), ('n04005630', 'prison', 0.05422082), ('n04033901', 'quill', 0.044538185), ('n04081281', 'restaurant', 0.04419249)]]

# %% [markdown]
# # Use Own Data

# %%
from google.colab import drive
from glob import glob
import cv2 as cv
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')

PATH = '/content/drive/My Drive/aa_images/10000_imgs_fixed_departure_v04'

images = [cv.imread(file, cv.COLOR_BGR2RGB) for file in glob(PATH + '/*.jpg')]
print(len(images))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 10000

# %%
if __name__ == '__main__':
    model = VGG19(include_top=True, weights='imagenet')
    
    img = []
    for i in range(len(images)):
      #img_path = 'cat.jpg'
      #img = image.load_img(img_path, target_size=(224, 224))
      img.append(cv.resize(images[i], (224, 224))) 
      x = image.img_to_array(img[i])
      x = np.expand_dims(x, axis=0)
      x = preprocess_input(x)
      print('Input image shape:', x.shape)

      preds = model.predict(x)
      print('Predicted:', decode_predictions(preds))
# Out:
# Streaming output truncated to the last 5000 lines.
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.071420334), ('n03160309', 'dam', 0.06590288), ('n04523525', 'vault', 0.04800803), ('n03065424', 'coil', 0.045053415), ('n02687172', 'aircraft_carrier', 0.03782871)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03065424', 'coil', 0.08357371), ('n04523525', 'vault', 0.07685595), ('n03160309', 'dam', 0.073666826), ('n04005630', 'prison', 0.054334912), ('n04347754', 'submarine', 0.037527792)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.09324153), ('n04523525', 'vault', 0.07457839), ('n03065424', 'coil', 0.053862095), ('n04005630', 'prison', 0.046494927), ('n04389033', 'tank', 0.03425633)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.12340542), ('n04523525', 'vault', 0.06711427), ('n04005630', 'prison', 0.050214782), ('n03065424', 'coil', 0.03933987), ('n04389033', 'tank', 0.03801488)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.083609805), ('n04523525', 'vault', 0.07201388), ('n04005630', 'prison', 0.056339905), ('n04389033', 'tank', 0.0411759), ('n02687172', 'aircraft_carrier', 0.03677165)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.09102744), ('n04523525', 'vault', 0.07654145), ('n04005630', 'prison', 0.055381108), ('n02917067', 'bullet_train', 0.05030151), ('n04347754', 'submarine', 0.047133364)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.11660709), ('n04005630', 'prison', 0.07857611), ('n02917067', 'bullet_train', 0.07264226), ('n04523525', 'vault', 0.06892046), ('n03895866', 'passenger_car', 0.044632144)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.14113814), ('n04005630', 'prison', 0.083807476), ('n03160309', 'dam', 0.06745095), ('n04523525', 'vault', 0.056626506), ('n03895866', 'passenger_car', 0.052413154)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.15194215), ('n04005630', 'prison', 0.07508076), ('n04523525', 'vault', 0.06238873), ('n03160309', 'dam', 0.06046424), ('n03895866', 'passenger_car', 0.051114958)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.23159502), ('n04005630', 'prison', 0.09696235), ('n03895866', 'passenger_car', 0.0705514), ('n04523525', 'vault', 0.0478141), ('n04389033', 'tank', 0.033261966)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.24239919), ('n04005630', 'prison', 0.07982492), ('n03895866', 'passenger_car', 0.062181883), ('n04523525', 'vault', 0.054044962), ('n04347754', 'submarine', 0.040941745)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.25296006), ('n04005630', 'prison', 0.06873358), ('n03895866', 'passenger_car', 0.064965986), ('n04523525', 'vault', 0.050259206), ('n04347754', 'submarine', 0.04433594)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.15931617), ('n04005630', 'prison', 0.08302443), ('n04523525', 'vault', 0.07036656), ('n03895866', 'passenger_car', 0.05496903), ('n04347754', 'submarine', 0.04293076)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.17288049), ('n04005630', 'prison', 0.10373379), ('n03895866', 'passenger_car', 0.0725116), ('n04523525', 'vault', 0.0628942), ('n04347754', 'submarine', 0.033787046)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.15363924), ('n04005630', 'prison', 0.11836021), ('n04523525', 'vault', 0.067478016), ('n03895866', 'passenger_car', 0.060315453), ('n04347754', 'submarine', 0.038721494)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.118513696), ('n04005630', 'prison', 0.08829076), ('n04523525', 'vault', 0.05804265), ('n03895866', 'passenger_car', 0.056141604), ('n04347754', 'submarine', 0.040711414)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.10633245), ('n04005630', 'prison', 0.10201769), ('n04523525', 'vault', 0.0638973), ('n04336792', 'stretcher', 0.045588274), ('n03895866', 'passenger_car', 0.04548438)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.10284008), ('n04005630', 'prison', 0.0885162), ('n04523525', 'vault', 0.056817524), ('n03895866', 'passenger_car', 0.04852897), ('n04336792', 'stretcher', 0.04352902)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.1026681), ('n04336792', 'stretcher', 0.0751167), ('n02917067', 'bullet_train', 0.060707685), ('n04523525', 'vault', 0.059888143), ('n03895866', 'passenger_car', 0.049839746)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.087052554), ('n04336792', 'stretcher', 0.072989), ('n02917067', 'bullet_train', 0.07182446), ('n04523525', 'vault', 0.053646185), ('n03895866', 'passenger_car', 0.050840344)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04336792', 'stretcher', 0.101788424), ('n04005630', 'prison', 0.062678844), ('n03895866', 'passenger_car', 0.0450136), ('n02917067', 'bullet_train', 0.044827864), ('n04347754', 'submarine', 0.042707384)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.06827279), ('n04336792', 'stretcher', 0.06585276), ('n04347754', 'submarine', 0.055473663), ('n03895866', 'passenger_car', 0.054414168), ('n02917067', 'bullet_train', 0.054187585)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.06792423), ('n04336792', 'stretcher', 0.063581), ('n04347754', 'submarine', 0.04422315), ('n04523525', 'vault', 0.03978237), ('n03895866', 'passenger_car', 0.03858562)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.07490162), ('n04523525', 'vault', 0.05147113), ('n03160309', 'dam', 0.047144223), ('n04613696', 'yurt', 0.038106624), ('n04336792', 'stretcher', 0.03422005)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.06012117), ('n04523525', 'vault', 0.051546082), ('n03160309', 'dam', 0.044567384), ('n04507155', 'umbrella', 0.040774792), ('n03933933', 'pier', 0.03430989)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.06941943), ('n04523525', 'vault', 0.057741057), ('n04005630', 'prison', 0.051267877), ('n03388043', 'fountain', 0.048079886), ('n04347754', 'submarine', 0.03477605)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04523525', 'vault', 0.07095481), ('n03160309', 'dam', 0.06415958), ('n03388043', 'fountain', 0.05371608), ('n04005630', 'prison', 0.048163917), ('n04346328', 'stupa', 0.04150776)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.07572874), ('n03388043', 'fountain', 0.058826696), ('n04523525', 'vault', 0.05505809), ('n03933933', 'pier', 0.049682334), ('n04005630', 'prison', 0.04617954)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.08905739), ('n03388043', 'fountain', 0.07583123), ('n04523525', 'vault', 0.054984055), ('n03933933', 'pier', 0.046864204), ('n04347754', 'submarine', 0.040377572)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.08904497), ('n03388043', 'fountain', 0.05850529), ('n04347754', 'submarine', 0.05150032), ('n04523525', 'vault', 0.048171006), ('n03933933', 'pier', 0.044700347)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.1218776), ('n04523525', 'vault', 0.062068928), ('n03388043', 'fountain', 0.061636224), ('n03895866', 'passenger_car', 0.055529613), ('n04347754', 'submarine', 0.050961427)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.10796523), ('n04347754', 'submarine', 0.08193459), ('n03895866', 'passenger_car', 0.0762387), ('n03388043', 'fountain', 0.059850685), ('n04523525', 'vault', 0.049631543)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.11543501), ('n04347754', 'submarine', 0.09317985), ('n03160309', 'dam', 0.083461545), ('n04523525', 'vault', 0.04759663), ('n04389033', 'tank', 0.04398899)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.11822129), ('n03895866', 'passenger_car', 0.117040806), ('n04347754', 'submarine', 0.06719538), ('n04523525', 'vault', 0.06294375), ('n04005630', 'prison', 0.055058047)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.12250886), ('n03160309', 'dam', 0.094576776), ('n04347754', 'submarine', 0.067459345), ('n04523525', 'vault', 0.06630622), ('n04005630', 'prison', 0.05133488)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.12866026), ('n03160309', 'dam', 0.07757757), ('n04347754', 'submarine', 0.07315735), ('n04005630', 'prison', 0.06351566), ('n04523525', 'vault', 0.062250257)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.15901689), ('n03160309', 'dam', 0.07218138), ('n04347754', 'submarine', 0.06861659), ('n04389033', 'tank', 0.063651204), ('n04005630', 'prison', 0.063155055)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.122654155), ('n04389033', 'tank', 0.06654688), ('n04347754', 'submarine', 0.063422546), ('n03160309', 'dam', 0.06183584), ('n04523525', 'vault', 0.057125814)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.13113232), ('n03160309', 'dam', 0.09467729), ('n04389033', 'tank', 0.0649786), ('n04347754', 'submarine', 0.060883783), ('n04523525', 'vault', 0.04303642)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.16762936), ('n03160309', 'dam', 0.07511914), ('n04389033', 'tank', 0.07205879), ('n04310018', 'steam_locomotive', 0.05218931), ('n04347754', 'submarine', 0.049858574)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.1312315), ('n03160309', 'dam', 0.085503526), ('n03388043', 'fountain', 0.056096617), ('n04389033', 'tank', 0.05599797), ('n04310018', 'steam_locomotive', 0.054585252)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.08064105), ('n04389033', 'tank', 0.06890021), ('n03160309', 'dam', 0.063082464), ('n03388043', 'fountain', 0.061010104), ('n04523525', 'vault', 0.04339781)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.108884744), ('n04523525', 'vault', 0.058648176), ('n04389033', 'tank', 0.055719886), ('n03388043', 'fountain', 0.050329555), ('n04005630', 'prison', 0.047888644)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.08772914), ('n03388043', 'fountain', 0.0669919), ('n03160309', 'dam', 0.060781326), ('n04523525', 'vault', 0.054566342), ('n04389033', 'tank', 0.044564858)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.102657005), ('n03160309', 'dam', 0.08006346), ('n03388043', 'fountain', 0.07010584), ('n04523525', 'vault', 0.054376733), ('n04005630', 'prison', 0.0426851)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03388043', 'fountain', 0.12671779), ('n03895866', 'passenger_car', 0.100310065), ('n03160309', 'dam', 0.08027066), ('n04310018', 'steam_locomotive', 0.048766013), ('n04389033', 'tank', 0.04806888)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.1936362), ('n03388043', 'fountain', 0.1336966), ('n03160309', 'dam', 0.06680646), ('n04310018', 'steam_locomotive', 0.048622113), ('n04005630', 'prison', 0.038317412)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.20466769), ('n03388043', 'fountain', 0.19425024), ('n03160309', 'dam', 0.07939711), ('n04523525', 'vault', 0.041940685), ('n04005630', 'prison', 0.03278306)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03388043', 'fountain', 0.23714903), ('n03895866', 'passenger_car', 0.13929139), ('n03160309', 'dam', 0.107073665), ('n04523525', 'vault', 0.04459099), ('n03933933', 'pier', 0.033309557)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03388043', 'fountain', 0.2428424), ('n03895866', 'passenger_car', 0.12283811), ('n03160309', 'dam', 0.09095966), ('n04523525', 'vault', 0.055914078), ('n04005630', 'prison', 0.03455712)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03388043', 'fountain', 0.16815935), ('n03895866', 'passenger_car', 0.15107109), ('n04523525', 'vault', 0.07564487), ('n03160309', 'dam', 0.064173594), ('n04005630', 'prison', 0.037497282)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.14472917), ('n04523525', 'vault', 0.102946445), ('n03388043', 'fountain', 0.09808615), ('n03160309', 'dam', 0.06776866), ('n04005630', 'prison', 0.048229117)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.29207554), ('n03388043', 'fountain', 0.057769194), ('n04523525', 'vault', 0.054723725), ('n03160309', 'dam', 0.047999043), ('n03788195', 'mosque', 0.043721445)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.29256743), ('n03388043', 'fountain', 0.054848414), ('n04310018', 'steam_locomotive', 0.048434034), ('n04523525', 'vault', 0.043810263), ('n03160309', 'dam', 0.039856445)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.29225585), ('n03388043', 'fountain', 0.06936384), ('n03160309', 'dam', 0.050005235), ('n04310018', 'steam_locomotive', 0.04483231), ('n04523525', 'vault', 0.043585256)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.23040664), ('n03388043', 'fountain', 0.105731584), ('n03160309', 'dam', 0.066471875), ('n04310018', 'steam_locomotive', 0.04842342), ('n03877845', 'palace', 0.038940717)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.26571837), ('n04310018', 'steam_locomotive', 0.05914352), ('n04346328', 'stupa', 0.04066077), ('n04005630', 'prison', 0.039414275), ('n03160309', 'dam', 0.03443687)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.34236225), ('n04310018', 'steam_locomotive', 0.09150898), ('n04347754', 'submarine', 0.06394592), ('n04005630', 'prison', 0.039062735), ('n02687172', 'aircraft_carrier', 0.027605874)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.4170653), ('n04310018', 'steam_locomotive', 0.092179395), ('n04347754', 'submarine', 0.043984443), ('n04346328', 'stupa', 0.03322188), ('n03272562', 'electric_locomotive', 0.028738094)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.4642511), ('n04310018', 'steam_locomotive', 0.10127531), ('n03272562', 'electric_locomotive', 0.035036042), ('n04346328', 'stupa', 0.032742504), ('n03220513', 'dome', 0.030750172)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.4460086), ('n04310018', 'steam_locomotive', 0.08086796), ('n03220513', 'dome', 0.04113291), ('n03272562', 'electric_locomotive', 0.036624722), ('n04346328', 'stupa', 0.03273933)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.37239134), ('n04310018', 'steam_locomotive', 0.077772506), ('n03220513', 'dome', 0.043812003), ('n03272562', 'electric_locomotive', 0.039436724), ('n03788195', 'mosque', 0.031668417)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.31444168), ('n04310018', 'steam_locomotive', 0.06751781), ('n03220513', 'dome', 0.03670102), ('n03272562', 'electric_locomotive', 0.036558077), ('n04005630', 'prison', 0.030325275)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.15284617), ('n03220513', 'dome', 0.05462881), ('n03788195', 'mosque', 0.04945731), ('n04310018', 'steam_locomotive', 0.038510393), ('n04346328', 'stupa', 0.03149069)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.11430069), ('n03220513', 'dome', 0.04401243), ('n03788195', 'mosque', 0.038019214), ('n04523525', 'vault', 0.033639725), ('n04005630', 'prison', 0.03180626)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.0978875), ('n04523525', 'vault', 0.040921908), ('n03160309', 'dam', 0.037330173), ('n04005630', 'prison', 0.036336906), ('n03220513', 'dome', 0.036263637)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.10099777), ('n02917067', 'bullet_train', 0.050212406), ('n03160309', 'dam', 0.03636809), ('n04347754', 'submarine', 0.0332401), ('n03220513', 'dome', 0.0328134)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.060370456), ('n03895866', 'passenger_car', 0.056746937), ('n04347754', 'submarine', 0.04679888), ('n02917067', 'bullet_train', 0.033430185), ('n02704792', 'amphibian', 0.033225797)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.10746213), ('n04347754', 'submarine', 0.0653221), ('n02917067', 'bullet_train', 0.051379792), ('n03895866', 'passenger_car', 0.04108469), ('n03673027', 'liner', 0.04015306)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04347754', 'submarine', 0.12816462), ('n03160309', 'dam', 0.1182062), ('n02917067', 'bullet_train', 0.049055494), ('n02859443', 'boathouse', 0.042010773), ('n03895866', 'passenger_car', 0.041023105)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04347754', 'submarine', 0.20383671), ('n03160309', 'dam', 0.12805615), ('n03933933', 'pier', 0.044065528), ('n02704792', 'amphibian', 0.042276204), ('n02687172', 'aircraft_carrier', 0.04056397)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04347754', 'submarine', 0.16023877), ('n03160309', 'dam', 0.08666438), ('n03673027', 'liner', 0.061108734), ('n03933933', 'pier', 0.061066117), ('n02859443', 'boathouse', 0.060803078)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03160309', 'dam', 0.10710815), ('n04347754', 'submarine', 0.09319489), ('n02859443', 'boathouse', 0.060431734), ('n03933933', 'pier', 0.057625744), ('n02704792', 'amphibian', 0.046582755)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04347754', 'submarine', 0.09924682), ('n02704792', 'amphibian', 0.083360195), ('n03160309', 'dam', 0.06318675), ('n03673027', 'liner', 0.05182655), ('n02859443', 'boathouse', 0.049347945)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04347754', 'submarine', 0.11897547), ('n02704792', 'amphibian', 0.08714435), ('n02687172', 'aircraft_carrier', 0.07474976), ('n03160309', 'dam', 0.051646564), ('n03673027', 'liner', 0.04494168)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02687172', 'aircraft_carrier', 0.19730306), ('n04347754', 'submarine', 0.14911678), ('n02704792', 'amphibian', 0.07763652), ('n03673027', 'liner', 0.065390214), ('n04389033', 'tank', 0.05760533)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04347754', 'submarine', 0.21422175), ('n03673027', 'liner', 0.10943975), ('n02687172', 'aircraft_carrier', 0.10322982), ('n03956157', 'planetarium', 0.05613214), ('n02704792', 'amphibian', 0.03324599)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.1539435), ('n04347754', 'submarine', 0.107345164), ('n03160309', 'dam', 0.07067994), ('n03673027', 'liner', 0.061182074), ('n04523525', 'vault', 0.047892626)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.11178917), ('n04347754', 'submarine', 0.07317556), ('n04523525', 'vault', 0.059529647), ('n03673027', 'liner', 0.044583492), ('n02687172', 'aircraft_carrier', 0.044140715)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.2427651), ('n04523525', 'vault', 0.058274377), ('n03673027', 'liner', 0.048719417), ('n04347754', 'submarine', 0.037719663), ('n02687172', 'aircraft_carrier', 0.030135382)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.18304877), ('n04523525', 'vault', 0.061888967), ('n03673027', 'liner', 0.047663927), ('n04347754', 'submarine', 0.029774915), ('n02825657', 'bell_cote', 0.0271188)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.1745107), ('n04523525', 'vault', 0.05429808), ('n03673027', 'liner', 0.038722005), ('n03160309', 'dam', 0.02342151), ('n04347754', 'submarine', 0.02102206)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.15672308), ('n04523525', 'vault', 0.057473548), ('n03160309', 'dam', 0.037520245), ('n03388043', 'fountain', 0.027587315), ('n03673027', 'liner', 0.027162978)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.15088767), ('n04523525', 'vault', 0.03859373), ('n03160309', 'dam', 0.032591578), ('n03673027', 'liner', 0.027303237), ('n03388043', 'fountain', 0.025357585)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.15587251), ('n03874293', 'paddlewheel', 0.028216088), ('n04347754', 'submarine', 0.026374696), ('n04523525', 'vault', 0.025552705), ('n02917067', 'bullet_train', 0.021505266)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.1308703), ('n02917067', 'bullet_train', 0.054809973), ('n01484850', 'great_white_shark', 0.026457513), ('n04347754', 'submarine', 0.025972392), ('n02927161', 'butcher_shop', 0.025909616)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.092964225), ('n02917067', 'bullet_train', 0.091047615), ('n04310018', 'steam_locomotive', 0.039586507), ('n04347754', 'submarine', 0.030624336), ('n02776631', 'bakery', 0.02691944)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.113867775), ('n02917067', 'bullet_train', 0.0783431), ('n03697007', 'lumbermill', 0.045249972), ('n02776631', 'bakery', 0.03366235), ('n04310018', 'steam_locomotive', 0.033085436)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03956157', 'planetarium', 0.088989645), ('n03697007', 'lumbermill', 0.06796313), ('n02917067', 'bullet_train', 0.06164006), ('n03457902', 'greenhouse', 0.043633197), ('n04310018', 'steam_locomotive', 0.03771028)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03697007', 'lumbermill', 0.090528384), ('n03788365', 'mosquito_net', 0.07770882), ('n02917067', 'bullet_train', 0.053663388), ('n03457902', 'greenhouse', 0.03519366), ('n03956157', 'planetarium', 0.031800114)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03697007', 'lumbermill', 0.0826464), ('n02917067', 'bullet_train', 0.082060345), ('n03788365', 'mosquito_net', 0.060559284), ('n03895866', 'passenger_car', 0.032111507), ('n03457902', 'greenhouse', 0.03172458)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.10326338), ('n03697007', 'lumbermill', 0.046383318), ('n03895866', 'passenger_car', 0.04029026), ('n03788365', 'mosquito_net', 0.035775807), ('n04523525', 'vault', 0.026199386)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.086117074), ('n04523525', 'vault', 0.039165746), ('n03788365', 'mosquito_net', 0.032566797), ('n03895866', 'passenger_car', 0.030370433), ('n03956157', 'planetarium', 0.030060794)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.076906696), ('n03895866', 'passenger_car', 0.041785523), ('n04081281', 'restaurant', 0.032322515), ('n03697007', 'lumbermill', 0.030384095), ('n02939185', 'caldron', 0.023584146)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.09922109), ('n03895866', 'passenger_car', 0.05079516), ('n03697007', 'lumbermill', 0.039656676), ('n04005630', 'prison', 0.032376077), ('n04081281', 'restaurant', 0.025662843)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.10692829), ('n03895866', 'passenger_car', 0.05670714), ('n03697007', 'lumbermill', 0.05191578), ('n04552348', 'warplane', 0.03543845), ('n04005630', 'prison', 0.032741908)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.15789692), ('n03895866', 'passenger_car', 0.0883648), ('n03697007', 'lumbermill', 0.059636038), ('n04310018', 'steam_locomotive', 0.045361694), ('n04552348', 'warplane', 0.041881535)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.11814363), ('n03895866', 'passenger_car', 0.113321066), ('n04310018', 'steam_locomotive', 0.06723653), ('n03697007', 'lumbermill', 0.058767404), ('n04552348', 'warplane', 0.050025426)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.101351164), ('n04310018', 'steam_locomotive', 0.089431085), ('n04389033', 'tank', 0.069237016), ('n03697007', 'lumbermill', 0.06760189), ('n04552348', 'warplane', 0.06508497)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04310018', 'steam_locomotive', 0.13345714), ('n03895866', 'passenger_car', 0.12026496), ('n04389033', 'tank', 0.08041445), ('n03697007', 'lumbermill', 0.054762688), ('n04552348', 'warplane', 0.054212347)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.071420334), ('n03160309', 'dam', 0.06590288), ('n04523525', 'vault', 0.04800803), ('n03065424', 'coil', 0.045053415), ('n02687172', 'aircraft_carrier', 0.03782871)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.07360261), ('n04347754', 'submarine', 0.06135318), ('n02917067', 'bullet_train', 0.06050966), ('n03895866', 'passenger_car', 0.047499083), ('n03160309', 'dam', 0.047289155)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.10173673), ('n02917067', 'bullet_train', 0.05521122), ('n04346328', 'stupa', 0.048810795), ('n04523525', 'vault', 0.048644107), ('n03895866', 'passenger_car', 0.041709334)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.13401417), ('n02917067', 'bullet_train', 0.08808609), ('n03895866', 'passenger_car', 0.06826828), ('n04523525', 'vault', 0.042998876), ('n04389033', 'tank', 0.034729153)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.13898952), ('n04005630', 'prison', 0.08998995), ('n03895866', 'passenger_car', 0.079788074), ('n04347754', 'submarine', 0.074478924), ('n04389033', 'tank', 0.045813736)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.09615966), ('n04347754', 'submarine', 0.08985378), ('n04005630', 'prison', 0.07021347), ('n03895866', 'passenger_car', 0.06656026), ('n04389033', 'tank', 0.064338565)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.17514785), ('n04347754', 'submarine', 0.08938334), ('n03895866', 'passenger_car', 0.06347189), ('n04005630', 'prison', 0.058582503), ('n04389033', 'tank', 0.040471263)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.18280882), ('n04347754', 'submarine', 0.088619694), ('n03895866', 'passenger_car', 0.06676119), ('n04005630', 'prison', 0.062294234), ('n04389033', 'tank', 0.045417592)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.17920946), ('n03895866', 'passenger_car', 0.072876334), ('n04005630', 'prison', 0.07208723), ('n04389033', 'tank', 0.04939174), ('n04347754', 'submarine', 0.04898865)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.20569374), ('n04005630', 'prison', 0.10532061), ('n03895866', 'passenger_car', 0.06625564), ('n04389033', 'tank', 0.035586074), ('n04347754', 'submarine', 0.028732445)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.23648715), ('n04005630', 'prison', 0.08916705), ('n03895866', 'passenger_car', 0.05455348), ('n04389033', 'tank', 0.03984606), ('n02791270', 'barbershop', 0.031264167)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.12577403), ('n04389033', 'tank', 0.11477144), ('n04005630', 'prison', 0.048589315), ('n04347754', 'submarine', 0.038879495), ('n03895866', 'passenger_car', 0.038069546)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04389033', 'tank', 0.06201166), ('n02791270', 'barbershop', 0.06167336), ('n02917067', 'bullet_train', 0.052389722), ('n03630383', 'lab_coat', 0.04778703), ('n04005630', 'prison', 0.04194309)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03630383', 'lab_coat', 0.07836889), ('n02917067', 'bullet_train', 0.05588287), ('n02791270', 'barbershop', 0.05506714), ('n04389033', 'tank', 0.0423053), ('n02687172', 'aircraft_carrier', 0.03626387)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.09083964), ('n04005630', 'prison', 0.051841065), ('n04389033', 'tank', 0.0511234), ('n04081281', 'restaurant', 0.049394045), ('n02791270', 'barbershop', 0.040064257)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.08577768), ('n02791270', 'barbershop', 0.084039964), ('n02927161', 'butcher_shop', 0.05334335), ('n04596742', 'wok', 0.03974502), ('n04005630', 'prison', 0.035599478)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02791270', 'barbershop', 0.12968594), ('n04081281', 'restaurant', 0.100143544), ('n02791124', 'barber_chair', 0.042203825), ('n04005630', 'prison', 0.03875848), ('n02927161', 'butcher_shop', 0.031699967)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02791270', 'barbershop', 0.124009445), ('n04081281', 'restaurant', 0.07760424), ('n02791124', 'barber_chair', 0.055424687), ('n03895866', 'passenger_car', 0.05414532), ('n03661043', 'library', 0.04587195)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.11635961), ('n03452741', 'grand_piano', 0.065081306), ('n02791270', 'barbershop', 0.0595735), ('n04081281', 'restaurant', 0.0571005), ('n02871525', 'bookshop', 0.05668949)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.108518496), ('n03661043', 'library', 0.09250059), ('n02871525', 'bookshop', 0.06007326), ('n04081281', 'restaurant', 0.04666635), ('n02791270', 'barbershop', 0.044075936)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.1186872), ('n03452741', 'grand_piano', 0.0908219), ('n02791270', 'barbershop', 0.073098406), ('n02871525', 'bookshop', 0.06641672), ('n04200800', 'shoe_shop', 0.036265705)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.14662294), ('n03661043', 'library', 0.14060019), ('n02871525', 'bookshop', 0.052390125), ('n02791270', 'barbershop', 0.045473292), ('n04081281', 'restaurant', 0.032282095)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.22072037), ('n03452741', 'grand_piano', 0.1477579), ('n02871525', 'bookshop', 0.088118315), ('n04081281', 'restaurant', 0.036683377), ('n04005630', 'prison', 0.029031204)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.37334728), ('n03452741', 'grand_piano', 0.086730495), ('n02871525', 'bookshop', 0.082562014), ('n04005630', 'prison', 0.044754356), ('n04081281', 'restaurant', 0.036124926)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.3409299), ('n03452741', 'grand_piano', 0.07046008), ('n04005630', 'prison', 0.06639159), ('n02871525', 'bookshop', 0.057787646), ('n04081281', 'restaurant', 0.033636637)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.2471089), ('n04005630', 'prison', 0.100829504), ('n02791270', 'barbershop', 0.056058083), ('n02791124', 'barber_chair', 0.05593656), ('n02871525', 'bookshop', 0.04455343)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.20375085), ('n04005630', 'prison', 0.1235783), ('n02791124', 'barber_chair', 0.05631764), ('n03452741', 'grand_piano', 0.048681993), ('n02791270', 'barbershop', 0.04758953)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.10797887), ('n02791270', 'barbershop', 0.10639965), ('n02791124', 'barber_chair', 0.09782192), ('n04005630', 'prison', 0.09724055), ('n04081281', 'restaurant', 0.048707154)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.097844735), ('n03661043', 'library', 0.07201939), ('n02776631', 'bakery', 0.05341614), ('n02791270', 'barbershop', 0.0500455), ('n04501370', 'turnstile', 0.042689182)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04005630', 'prison', 0.106636345), ('n03452741', 'grand_piano', 0.05597462), ('n03661043', 'library', 0.05193367), ('n02788148', 'bannister', 0.050730698), ('n04081281', 'restaurant', 0.048812717)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.0924521), ('n04005630', 'prison', 0.06763989), ('n02788148', 'bannister', 0.06283023), ('n03661043', 'library', 0.045634005), ('n04081281', 'restaurant', 0.04050339)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.077085815), ('n02788148', 'bannister', 0.0606542), ('n04081281', 'restaurant', 0.048876684), ('n04005630', 'prison', 0.04112167), ('n02776631', 'bakery', 0.03494105)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.093041725), ('n04081281', 'restaurant', 0.06686013), ('n02917067', 'bullet_train', 0.043696556), ('n02776631', 'bakery', 0.042887654), ('n02927161', 'butcher_shop', 0.037417963)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.13182566), ('n04081281', 'restaurant', 0.06149238), ('n03895866', 'passenger_car', 0.042732473), ('n03447447', 'gondola', 0.040038645), ('n02917067', 'bullet_train', 0.039731838)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.22791238), ('n04081281', 'restaurant', 0.07696145), ('n03895866', 'passenger_car', 0.0555318), ('n03447447', 'gondola', 0.045237478), ('n02917067', 'bullet_train', 0.043983724)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.15444404), ('n03895866', 'passenger_car', 0.13813142), ('n02917067', 'bullet_train', 0.07661848), ('n04081281', 'restaurant', 0.06708996), ('n03661043', 'library', 0.03163167)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.16077496), ('n03895866', 'passenger_car', 0.15675278), ('n02917067', 'bullet_train', 0.06557032), ('n04081281', 'restaurant', 0.059098557), ('n03661043', 'library', 0.03717952)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.14285256), ('n03452741', 'grand_piano', 0.14009167), ('n02917067', 'bullet_train', 0.08132077), ('n04081281', 'restaurant', 0.060209397), ('n03661043', 'library', 0.051913947)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.12257564), ('n03895866', 'passenger_car', 0.09545527), ('n03661043', 'library', 0.07306351), ('n04081281', 'restaurant', 0.070314065), ('n02917067', 'bullet_train', 0.042399444)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.15288003), ('n04081281', 'restaurant', 0.06203211), ('n03661043', 'library', 0.06027779), ('n03895866', 'passenger_car', 0.041379947), ('n03447447', 'gondola', 0.026022032)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03452741', 'grand_piano', 0.11374184), ('n03661043', 'library', 0.11066893), ('n04081281', 'restaurant', 0.068275474), ('n04200800', 'shoe_shop', 0.03277182), ('n04005630', 'prison', 0.031397328)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.13982004), ('n04081281', 'restaurant', 0.09193214), ('n04200800', 'shoe_shop', 0.05164806), ('n03452741', 'grand_piano', 0.046422474), ('n02791270', 'barbershop', 0.03946943)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.14025386), ('n04081281', 'restaurant', 0.10362729), ('n02791270', 'barbershop', 0.05289545), ('n04005630', 'prison', 0.042362887), ('n04200800', 'shoe_shop', 0.03697622)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.11733343), ('n03661043', 'library', 0.10681883), ('n02791270', 'barbershop', 0.054233786), ('n04005630', 'prison', 0.04415795), ('n03899768', 'patio', 0.036443982)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.11112136), ('n04081281', 'restaurant', 0.098885566), ('n03899768', 'patio', 0.063741654), ('n03452741', 'grand_piano', 0.047853153), ('n04005630', 'prison', 0.036552437)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.13159718), ('n03661043', 'library', 0.099978946), ('n03899768', 'patio', 0.09314606), ('n03201208', 'dining_table', 0.062207744), ('n04239074', 'sliding_door', 0.03476782)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.118545905), ('n03899768', 'patio', 0.109467685), ('n03661043', 'library', 0.07183326), ('n03201208', 'dining_table', 0.05804926), ('n03761084', 'microwave', 0.0346025)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03899768', 'patio', 0.1969609), ('n04081281', 'restaurant', 0.095592044), ('n03661043', 'library', 0.046947837), ('n03201208', 'dining_table', 0.041936416), ('n04239074', 'sliding_door', 0.035321698)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03899768', 'patio', 0.172224), ('n04081281', 'restaurant', 0.09483764), ('n03661043', 'library', 0.08648755), ('n03201208', 'dining_table', 0.04134742), ('n04239074', 'sliding_door', 0.030768901)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03899768', 'patio', 0.1737209), ('n03661043', 'library', 0.11341916), ('n04081281', 'restaurant', 0.09221532), ('n03201208', 'dining_table', 0.046377175), ('n03457902', 'greenhouse', 0.037324846)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03899768', 'patio', 0.15549967), ('n03661043', 'library', 0.11120376), ('n04081281', 'restaurant', 0.06305739), ('n03201208', 'dining_table', 0.042615946), ('n03376595', 'folding_chair', 0.040149793)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03899768', 'patio', 0.1331216), ('n04081281', 'restaurant', 0.073667586), ('n03661043', 'library', 0.06823783), ('n03376595', 'folding_chair', 0.03852163), ('n03201208', 'dining_table', 0.035152398)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03899768', 'patio', 0.15954788), ('n04081281', 'restaurant', 0.08020134), ('n03661043', 'library', 0.042940155), ('n04005630', 'prison', 0.033437073), ('n03376595', 'folding_chair', 0.029104248)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03899768', 'patio', 0.1160048), ('n04081281', 'restaurant', 0.0489375), ('n04389033', 'tank', 0.04240571), ('n04493381', 'tub', 0.03267133), ('n03776460', 'mobile_home', 0.030999228)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04389033', 'tank', 0.0755214), ('n02704792', 'amphibian', 0.062378854), ('n03899768', 'patio', 0.054423295), ('n03895866', 'passenger_car', 0.040904213), ('n02917067', 'bullet_train', 0.040702973)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04389033', 'tank', 0.07521555), ('n02704792', 'amphibian', 0.053240094), ('n03457902', 'greenhouse', 0.05169154), ('n03899768', 'patio', 0.04309023), ('n03478589', 'half_track', 0.042512048)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.10980965), ('n03895866', 'passenger_car', 0.098717816), ('n03272562', 'electric_locomotive', 0.072028935), ('n03457902', 'greenhouse', 0.06775103), ('n04389033', 'tank', 0.046911918)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.27369773), ('n03895866', 'passenger_car', 0.20435615), ('n03272562', 'electric_locomotive', 0.07118646), ('n04335435', 'streetcar', 0.07023088), ('n03457902', 'greenhouse', 0.06021476)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.27189937), ('n03895866', 'passenger_car', 0.21593176), ('n04335435', 'streetcar', 0.076221414), ('n03272562', 'electric_locomotive', 0.06057396), ('n03457902', 'greenhouse', 0.04202095)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.21129352), ('n02917067', 'bullet_train', 0.18237028), ('n04335435', 'streetcar', 0.07915132), ('n03272562', 'electric_locomotive', 0.06207665), ('n03457902', 'greenhouse', 0.047482934)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.22881751), ('n02917067', 'bullet_train', 0.20456566), ('n03272562', 'electric_locomotive', 0.0866449), ('n04335435', 'streetcar', 0.07058545), ('n03457902', 'greenhouse', 0.041164786)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.32536724), ('n03895866', 'passenger_car', 0.24938707), ('n03272562', 'electric_locomotive', 0.14811942), ('n04335435', 'streetcar', 0.047662906), ('n02860847', 'bobsled', 0.020084856)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.2511052), ('n03895866', 'passenger_car', 0.25049743), ('n03272562', 'electric_locomotive', 0.12491966), ('n04335435', 'streetcar', 0.037825733), ('n02860847', 'bobsled', 0.029520497)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.30839363), ('n02917067', 'bullet_train', 0.20300679), ('n03272562', 'electric_locomotive', 0.13381), ('n04335435', 'streetcar', 0.03651511), ('n02860847', 'bobsled', 0.033420008)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.39889887), ('n02917067', 'bullet_train', 0.1730392), ('n03272562', 'electric_locomotive', 0.115622036), ('n04335435', 'streetcar', 0.040384408), ('n04310018', 'steam_locomotive', 0.027745688)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.44186905), ('n02917067', 'bullet_train', 0.14038225), ('n03272562', 'electric_locomotive', 0.11485989), ('n04335435', 'streetcar', 0.054367535), ('n04310018', 'steam_locomotive', 0.036466856)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03895866', 'passenger_car', 0.37406802), ('n02917067', 'bullet_train', 0.2597816), ('n03272562', 'electric_locomotive', 0.13330826), ('n04335435', 'streetcar', 0.041549757), ('n04310018', 'steam_locomotive', 0.032471664)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.29902226), ('n03895866', 'passenger_car', 0.24787548), ('n03272562', 'electric_locomotive', 0.13784394), ('n02704792', 'amphibian', 0.0345192), ('n04310018', 'steam_locomotive', 0.030913612)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.36914834), ('n03895866', 'passenger_car', 0.19679782), ('n03272562', 'electric_locomotive', 0.09091524), ('n02860847', 'bobsled', 0.049668156), ('n02704792', 'amphibian', 0.04086838)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.5828141), ('n03895866', 'passenger_car', 0.1278156), ('n03272562', 'electric_locomotive', 0.038120806), ('n02860847', 'bobsled', 0.02978854), ('n03447447', 'gondola', 0.027393831)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.4667133), ('n03895866', 'passenger_car', 0.15154636), ('n04347754', 'submarine', 0.050966762), ('n03447447', 'gondola', 0.043927632), ('n02860847', 'bobsled', 0.031526607)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.42426845), ('n03895866', 'passenger_car', 0.10553245), ('n04347754', 'submarine', 0.06107261), ('n03447447', 'gondola', 0.05424559), ('n02860847', 'bobsled', 0.03713954)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.22293414), ('n03447447', 'gondola', 0.09490862), ('n02860847', 'bobsled', 0.06627787), ('n04310018', 'steam_locomotive', 0.055380058), ('n03895866', 'passenger_car', 0.038458504)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.26500928), ('n03447447', 'gondola', 0.117047906), ('n04347754', 'submarine', 0.057728305), ('n02860847', 'bobsled', 0.040923145), ('n04310018', 'steam_locomotive', 0.033411536)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.20133734), ('n03447447', 'gondola', 0.17766516), ('n04347754', 'submarine', 0.1259006), ('n04335435', 'streetcar', 0.03284246), ('n02860847', 'bobsled', 0.032157067)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.20153633), ('n03447447', 'gondola', 0.19978613), ('n04347754', 'submarine', 0.14369375), ('n02860847', 'bobsled', 0.035275914), ('n04335435', 'streetcar', 0.032953314)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03447447', 'gondola', 0.2143039), ('n04347754', 'submarine', 0.16572776), ('n02917067', 'bullet_train', 0.11525206), ('n04335435', 'streetcar', 0.028830085), ('n03160309', 'dam', 0.024558466)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03447447', 'gondola', 0.23182854), ('n04347754', 'submarine', 0.22079754), ('n02917067', 'bullet_train', 0.08881902), ('n03160309', 'dam', 0.03434785), ('n03216828', 'dock', 0.03084435)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03447447', 'gondola', 0.2742485), ('n04347754', 'submarine', 0.18851592), ('n02917067', 'bullet_train', 0.093313865), ('n03216828', 'dock', 0.05539726), ('n02860847', 'bobsled', 0.035174012)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03447447', 'gondola', 0.29499364), ('n04347754', 'submarine', 0.20633762), ('n02917067', 'bullet_train', 0.13588387), ('n03216828', 'dock', 0.06138847), ('n02860847', 'bobsled', 0.024394082)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.2522303), ('n04347754', 'submarine', 0.24775754), ('n03447447', 'gondola', 0.13850795), ('n03216828', 'dock', 0.051974867), ('n02860847', 'bobsled', 0.031562887)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04347754', 'submarine', 0.24067299), ('n02917067', 'bullet_train', 0.19433887), ('n03447447', 'gondola', 0.11317108), ('n03216828', 'dock', 0.04349963), ('n02860847', 'bobsled', 0.040924374)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04347754', 'submarine', 0.13753021), ('n02917067', 'bullet_train', 0.12954314), ('n03447447', 'gondola', 0.11804366), ('n02860847', 'bobsled', 0.095443904), ('n04252225', 'snowplow', 0.049987763)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03447447', 'gondola', 0.12789112), ('n04347754', 'submarine', 0.11165815), ('n02860847', 'bobsled', 0.101644374), ('n02917067', 'bullet_train', 0.09986993), ('n04252225', 'snowplow', 0.056712087)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02860847', 'bobsled', 0.13884822), ('n02917067', 'bullet_train', 0.12322992), ('n04347754', 'submarine', 0.10999239), ('n03447447', 'gondola', 0.09956621), ('n04252225', 'snowplow', 0.04907253)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.22000398), ('n02860847', 'bobsled', 0.10674079), ('n04347754', 'submarine', 0.08334084), ('n03447447', 'gondola', 0.07445552), ('n03216828', 'dock', 0.027610697)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.16707486), ('n02860847', 'bobsled', 0.11502369), ('n04347754', 'submarine', 0.11028246), ('n03447447', 'gondola', 0.073398575), ('n03160309', 'dam', 0.02973693)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.17951079), ('n02860847', 'bobsled', 0.16080022), ('n04347754', 'submarine', 0.060755663), ('n03447447', 'gondola', 0.059265427), ('n03160309', 'dam', 0.028857851)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02860847', 'bobsled', 0.2593744), ('n02917067', 'bullet_train', 0.20315804), ('n03447447', 'gondola', 0.075936005), ('n04347754', 'submarine', 0.040109627), ('n04252225', 'snowplow', 0.029993244)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.19003902), ('n02860847', 'bobsled', 0.179107), ('n03447447', 'gondola', 0.10158512), ('n04347754', 'submarine', 0.04676569), ('n04005630', 'prison', 0.033592187)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02917067', 'bullet_train', 0.20560429), ('n02860847', 'bobsled', 0.15058193), ('n04347754', 'submarine', 0.084083214), ('n03447447', 'gondola', 0.055805184), ('n03160309', 'dam', 0.03616979)]]
# ...
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.26352698), ('n04081281', 'restaurant', 0.17823137), ('n04200800', 'shoe_shop', 0.097502016), ('n02791270', 'barbershop', 0.035797447), ('n03787032', 'mortarboard', 0.025559677)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n02791270', 'barbershop', 0.13492736), ('n04200800', 'shoe_shop', 0.10093066), ('n04081281', 'restaurant', 0.09952293), ('n04336792', 'stretcher', 0.04864554), ('n03661043', 'library', 0.045287076)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.09388678), ('n04336792', 'stretcher', 0.09160809), ('n03661043', 'library', 0.06874713), ('n02791270', 'barbershop', 0.06868389), ('n04200800', 'shoe_shop', 0.04132374)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.14140993), ('n03661043', 'library', 0.07677181), ('n04200800', 'shoe_shop', 0.058080368), ('n02791270', 'barbershop', 0.051483445), ('n04336792', 'stretcher', 0.040480614)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.2767226), ('n03661043', 'library', 0.114829674), ('n02791270', 'barbershop', 0.050257355), ('n03201208', 'dining_table', 0.04311191), ('n03899768', 'patio', 0.038716797)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.38016298), ('n03661043', 'library', 0.085816935), ('n03201208', 'dining_table', 0.059889827), ('n02791270', 'barbershop', 0.031966697), ('n03899768', 'patio', 0.030368637)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.35870385), ('n03661043', 'library', 0.14191471), ('n03201208', 'dining_table', 0.06424708), ('n04200800', 'shoe_shop', 0.029690735), ('n03179701', 'desk', 0.028388787)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.27274764), ('n03661043', 'library', 0.19101073), ('n03201208', 'dining_table', 0.06442949), ('n03179701', 'desk', 0.04174105), ('n03376595', 'folding_chair', 0.034710925)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.2329176), ('n03661043', 'library', 0.21215522), ('n03201208', 'dining_table', 0.040935837), ('n03179701', 'desk', 0.038198393), ('n02791270', 'barbershop', 0.037491094)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.32139748), ('n04081281', 'restaurant', 0.20532829), ('n03201208', 'dining_table', 0.036795553), ('n03179701', 'desk', 0.034166478), ('n02791270', 'barbershop', 0.030433625)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.47798598), ('n04081281', 'restaurant', 0.2010753), ('n03201208', 'dining_table', 0.0397487), ('n03179701', 'desk', 0.039605778), ('n02791270', 'barbershop', 0.020549776)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.60172874), ('n04081281', 'restaurant', 0.15361764), ('n03201208', 'dining_table', 0.041156985), ('n03179701', 'desk', 0.031293627), ('n03376595', 'folding_chair', 0.014907644)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.58100843), ('n04081281', 'restaurant', 0.16591951), ('n03201208', 'dining_table', 0.059413157), ('n03179701', 'desk', 0.036854144), ('n03376595', 'folding_chair', 0.018016532)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.48936152), ('n04081281', 'restaurant', 0.17585039), ('n03201208', 'dining_table', 0.076925755), ('n03179701', 'desk', 0.03844629), ('n03376595', 'folding_chair', 0.034935772)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.60212684), ('n04081281', 'restaurant', 0.10986018), ('n03201208', 'dining_table', 0.051183462), ('n03376595', 'folding_chair', 0.043212123), ('n03179701', 'desk', 0.04069722)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.5714784), ('n04081281', 'restaurant', 0.1255957), ('n03201208', 'dining_table', 0.062971376), ('n03179701', 'desk', 0.049240675), ('n03376595', 'folding_chair', 0.04545796)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.5553077), ('n04081281', 'restaurant', 0.12770396), ('n03201208', 'dining_table', 0.081783555), ('n03179701', 'desk', 0.053159587), ('n03376595', 'folding_chair', 0.040610388)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.6653689), ('n04081281', 'restaurant', 0.111862145), ('n03201208', 'dining_table', 0.052302733), ('n03179701', 'desk', 0.030210774), ('n03376595', 'folding_chair', 0.024128983)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.7047523), ('n04081281', 'restaurant', 0.08057905), ('n03201208', 'dining_table', 0.052098535), ('n03179701', 'desk', 0.024619887), ('n03376595', 'folding_chair', 0.016919242)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.6112809), ('n04081281', 'restaurant', 0.072007015), ('n03201208', 'dining_table', 0.057938885), ('n03179701', 'desk', 0.04095483), ('n03376595', 'folding_chair', 0.01669638)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.5764073), ('n04081281', 'restaurant', 0.06706542), ('n03201208', 'dining_table', 0.058577448), ('n03179701', 'desk', 0.04543687), ('n03642806', 'laptop', 0.017038234)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.4568876), ('n04081281', 'restaurant', 0.0944386), ('n03179701', 'desk', 0.07422984), ('n03201208', 'dining_table', 0.074206695), ('n03782006', 'monitor', 0.016275547)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.32212153), ('n04081281', 'restaurant', 0.14334998), ('n03201208', 'dining_table', 0.09800682), ('n03179701', 'desk', 0.067506306), ('n03452741', 'grand_piano', 0.029018946)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.26948008), ('n04081281', 'restaurant', 0.12803106), ('n03201208', 'dining_table', 0.09187277), ('n03179701', 'desk', 0.08615077), ('n02791270', 'barbershop', 0.027657872)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.2503685), ('n04081281', 'restaurant', 0.16871662), ('n03201208', 'dining_table', 0.085001975), ('n03179701', 'desk', 0.08176135), ('n02791270', 'barbershop', 0.035580195)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.21519588), ('n04081281', 'restaurant', 0.16737287), ('n03201208', 'dining_table', 0.10206285), ('n03179701', 'desk', 0.07195449), ('n02791270', 'barbershop', 0.032899607)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.23140287), ('n04081281', 'restaurant', 0.1182595), ('n03179701', 'desk', 0.102132455), ('n03201208', 'dining_table', 0.08138665), ('n02791270', 'barbershop', 0.032720413)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03661043', 'library', 0.18627033), ('n04081281', 'restaurant', 0.15071775), ('n03201208', 'dining_table', 0.090168856), ('n03179701', 'desk', 0.089749165), ('n02791270', 'barbershop', 0.03383953)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.16353686), ('n03661043', 'library', 0.107806556), ('n03201208', 'dining_table', 0.09135491), ('n03179701', 'desk', 0.0773264), ('n02791270', 'barbershop', 0.029831694)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.157606), ('n03201208', 'dining_table', 0.08772417), ('n03179701', 'desk', 0.074917234), ('n03661043', 'library', 0.06557636), ('n04200800', 'shoe_shop', 0.041106414)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.17748618), ('n03201208', 'dining_table', 0.113003306), ('n03179701', 'desk', 0.07126656), ('n03661043', 'library', 0.045469142), ('n04200800', 'shoe_shop', 0.035385173)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.15179625), ('n03201208', 'dining_table', 0.105865195), ('n03179701', 'desk', 0.069176786), ('n04200800', 'shoe_shop', 0.03470139), ('n03452741', 'grand_piano', 0.030105514)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.120347366), ('n03201208', 'dining_table', 0.097413994), ('n03179701', 'desk', 0.09668158), ('n04200800', 'shoe_shop', 0.054628927), ('n03630383', 'lab_coat', 0.03159769)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04081281', 'restaurant', 0.104206), ('n03179701', 'desk', 0.084838174), ('n03201208', 'dining_table', 0.075292245), ('n04200800', 'shoe_shop', 0.07072158), ('n02791270', 'barbershop', 0.052377634)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03179701', 'desk', 0.08906181), ('n04200800', 'shoe_shop', 0.07296986), ('n04081281', 'restaurant', 0.067075066), ('n03201208', 'dining_table', 0.060503867), ('n02791270', 'barbershop', 0.047252737)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n03179701', 'desk', 0.118885495), ('n04200800', 'shoe_shop', 0.08194287), ('n03452741', 'grand_piano', 0.047329538), ('n04081281', 'restaurant', 0.042662468), ('n03201208', 'dining_table', 0.0420124)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.10589686), ('n03179701', 'desk', 0.09565351), ('n04081281', 'restaurant', 0.054032154), ('n03452741', 'grand_piano', 0.047065586), ('n02791270', 'barbershop', 0.041291058)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.12870273), ('n03179701', 'desk', 0.07587515), ('n04081281', 'restaurant', 0.05672022), ('n02791270', 'barbershop', 0.033809118), ('n03452741', 'grand_piano', 0.0321968)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.10716924), ('n03179701', 'desk', 0.05808396), ('n04081281', 'restaurant', 0.036859598), ('n03452741', 'grand_piano', 0.034575097), ('n02791270', 'barbershop', 0.03381316)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.122645505), ('n03179701', 'desk', 0.061405562), ('n03452741', 'grand_piano', 0.03979355), ('n04081281', 'restaurant', 0.029410187), ('n04590129', 'window_shade', 0.025541741)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.12098413), ('n03179701', 'desk', 0.057979908), ('n03452741', 'grand_piano', 0.03577898), ('n04590129', 'window_shade', 0.032998804), ('n04081281', 'restaurant', 0.02980669)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.12549582), ('n03179701', 'desk', 0.043675434), ('n04239074', 'sliding_door', 0.033422068), ('n04590129', 'window_shade', 0.03183654), ('n03452741', 'grand_piano', 0.025620088)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.081036), ('n03179701', 'desk', 0.03886511), ('n04239074', 'sliding_door', 0.03528249), ('n04590129', 'window_shade', 0.033002436), ('n02791270', 'barbershop', 0.02904986)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.0789054), ('n03179701', 'desk', 0.051914304), ('n04239074', 'sliding_door', 0.035202112), ('n02860847', 'bobsled', 0.03002457), ('n04590129', 'window_shade', 0.029622875)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.071891986), ('n03179701', 'desk', 0.055322487), ('n04590129', 'window_shade', 0.036772836), ('n04239074', 'sliding_door', 0.031418398), ('n04344873', 'studio_couch', 0.025003605)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.09919297), ('n03179701', 'desk', 0.043008618), ('n04590129', 'window_shade', 0.034743533), ('n04239074', 'sliding_door', 0.02622633), ('n02791270', 'barbershop', 0.022911407)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.08501614), ('n03179701', 'desk', 0.051074672), ('n04590129', 'window_shade', 0.043308597), ('n04344873', 'studio_couch', 0.02207159), ('n04239074', 'sliding_door', 0.021966564)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.09692429), ('n03179701', 'desk', 0.055695947), ('n04590129', 'window_shade', 0.0440811), ('n04081281', 'restaurant', 0.024156108), ('n04344873', 'studio_couch', 0.019403307)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.10595036), ('n04590129', 'window_shade', 0.04775762), ('n03179701', 'desk', 0.045493394), ('n04081281', 'restaurant', 0.025133781), ('n04344873', 'studio_couch', 0.022026844)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.08796923), ('n03179701', 'desk', 0.050913002), ('n04590129', 'window_shade', 0.044676527), ('n04081281', 'restaurant', 0.0352745), ('n04344873', 'studio_couch', 0.023015486)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04200800', 'shoe_shop', 0.07071906), ('n03179701', 'desk', 0.0561209), ('n04590129', 'window_shade', 0.04209278), ('n04081281', 'restaurant', 0.031522956), ('n04344873', 'studio_couch', 0.024598084)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.051331498), ('n03179701', 'desk', 0.049500816), ('n04200800', 'shoe_shop', 0.047773402), ('n04081281', 'restaurant', 0.032032046), ('n04493381', 'tub', 0.030685306)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.055270337), ('n03179701', 'desk', 0.04817837), ('n04200800', 'shoe_shop', 0.04416639), ('n04493381', 'tub', 0.035122484), ('n04081281', 'restaurant', 0.027044116)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.05273474), ('n04200800', 'shoe_shop', 0.043183327), ('n03179701', 'desk', 0.042899482), ('n04493381', 'tub', 0.0365455), ('n04081281', 'restaurant', 0.03247298)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.04971597), ('n03179701', 'desk', 0.0406595), ('n04200800', 'shoe_shop', 0.039272312), ('n04081281', 'restaurant', 0.034214154), ('n04493381', 'tub', 0.032291785)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.05344802), ('n03179701', 'desk', 0.036058705), ('n04081281', 'restaurant', 0.035625458), ('n04200800', 'shoe_shop', 0.03323924), ('n04344873', 'studio_couch', 0.031269975)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.06318948), ('n03179701', 'desk', 0.0421451), ('n04200800', 'shoe_shop', 0.03691848), ('n04081281', 'restaurant', 0.035967268), ('n04344873', 'studio_couch', 0.03168878)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.052819528), ('n03179701', 'desk', 0.037647966), ('n04200800', 'shoe_shop', 0.036695134), ('n04081281', 'restaurant', 0.030643621), ('n04493381', 'tub', 0.027903926)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.05596139), ('n04200800', 'shoe_shop', 0.039919574), ('n03179701', 'desk', 0.03599674), ('n04344873', 'studio_couch', 0.032664753), ('n04493381', 'tub', 0.024751972)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.054104358), ('n03179701', 'desk', 0.047135763), ('n04200800', 'shoe_shop', 0.041882034), ('n04344873', 'studio_couch', 0.027993692), ('n03529860', 'home_theater', 0.024111679)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.043764215), ('n03179701', 'desk', 0.043500632), ('n04200800', 'shoe_shop', 0.03641169), ('n03529860', 'home_theater', 0.02727886), ('n04344873', 'studio_couch', 0.022872178)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.045914825), ('n03179701', 'desk', 0.045416724), ('n04200800', 'shoe_shop', 0.038439598), ('n03529860', 'home_theater', 0.02724919), ('n04344873', 'studio_couch', 0.023696698)]]
# Input image shape: (1, 224, 224, 3)
# Predicted: [[('n04590129', 'window_shade', 0.040888466), ('n04200800', 'shoe_shop', 0.03888826), ('n03179701', 'desk', 0.0334703), ('n03529860', 'home_theater', 0.029388813), ('n04493381', 'tub', 0.02683821)]]
